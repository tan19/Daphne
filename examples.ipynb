# %%
# %load_ext autoreload
# %autoreload 2

from model.black_scholes import BlackScholes

import numpy as np
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]

bs = BlackScholes()
bs.pv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# array([1.15129439])

# %%
bs.spot = np.linspace(0, 200, num=100)
bs.plot
# Out:
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:88: RuntimeWarning: invalid value encountered in true_divide
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):

# %%
bs.tenor = np.array([1/12])
bs.spot = np.linspace(0, 200, num=100)
bs.plot
# Out:
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:88: RuntimeWarning: invalid value encountered in true_divide
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
# c:\Users\XiMTa\Dropbox\Writings\GitHub\Daphne\model\black_scholes.py:48: RuntimeWarning: divide by zero encountered in log
#   def delta(self):
