# %%
# %load_ext autoreload
# %autoreload 2

from model.black_scholes import BlackScholes

import numpy as np
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]

bs = BlackScholes()

bs.plot('spot', np.linspace(80, 120, num=100))

plt.figure()
bs.plot('vol', np.linspace(0.10, 0.30, num=100))

plt.figure()
bs.plot('tenor', np.linspace(1/12, 1.0, num=100))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
